# %%
# %pip install numpy pandas matplot seaborn openpyxl
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
# Out:
# Requirement already satisfied: numpy in ./env/lib/python3.9/site-packages (1.24.3)
# Requirement already satisfied: pandas in ./env/lib/python3.9/site-packages (2.0.0)
# Requirement already satisfied: matplot in ./env/lib/python3.9/site-packages (0.1.9)
# Requirement already satisfied: seaborn in ./env/lib/python3.9/site-packages (0.12.2)
# Requirement already satisfied: openpyxl in ./env/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./env/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./env/lib/python3.9/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pyloco>=0.0.134 in ./env/lib/python3.9/site-packages (from matplot) (0.0.139)
# Requirement already satisfied: matplotlib>=3.1.1 in ./env/lib/python3.9/site-packages (from matplot) (3.7.1)
# Requirement already satisfied: et-xmlfile in ./env/lib/python3.9/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./env/lib/python3.9/site-packages (from matplotlib>=3.1.1->matplot) (5.12.0)
# Requirement already satisfied: ushlex in ./env/lib/python3.9/site-packages (from pyloco>=0.0.134->matplot) (0.99.1)
# Requirement already satisfied: websocket-client in ./env/lib/python3.9/site-packages (from pyloco>=0.0.134->matplot) (1.5.1)
# Requirement already satisfied: twine in ./env/lib/python3.9/site-packages (from pyloco>=0.0.134->matplot) (4.0.2)
# Requirement already satisfied: typing in ./env/lib/python3.9/site-packages (from pyloco>=0.0.134->matplot) (3.7.4.3)
# Requirement already satisfied: SimpleWebSocketServer in ./env/lib/python3.9/site-packages (from pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in ./env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.1.1->matplot) (3.15.0)
# Requirement already satisfied: pkginfo>=1.8.1 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (1.9.6)
# Requirement already satisfied: readme-renderer>=35.0 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (37.3)
# Requirement already satisfied: requests>=2.20 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (2.28.2)
# Requirement already satisfied: requests-toolbelt!=0.9.0,>=0.8.0 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (0.10.1)
# Requirement already satisfied: urllib3>=1.26.0 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (1.26.15)
# Requirement already satisfied: importlib-metadata>=3.6 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (6.6.0)
# Requirement already satisfied: keyring>=15.1 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (23.13.1)
# Requirement already satisfied: rfc3986>=1.4.0 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (2.0.0)
# Requirement already satisfied: rich>=12.0.0 in ./env/lib/python3.9/site-packages (from twine->pyloco>=0.0.134->matplot) (13.3.4)
# Requirement already satisfied: jaraco.classes in ./env/lib/python3.9/site-packages (from keyring>=15.1->twine->pyloco>=0.0.134->matplot) (3.2.3)
# Requirement already satisfied: bleach>=2.1.0 in ./env/lib/python3.9/site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (6.0.0)
# Requirement already satisfied: docutils>=0.13.1 in ./env/lib/python3.9/site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.19)
# Requirement already satisfied: Pygments>=2.5.1 in ./env/lib/python3.9/site-packages (from readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (2.15.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./env/lib/python3.9/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./env/lib/python3.9/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./env/lib/python3.9/site-packages (from requests>=2.20->twine->pyloco>=0.0.134->matplot) (2022.12.7)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in ./env/lib/python3.9/site-packages (from rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (2.2.0)
# Requirement already satisfied: webencodings in ./env/lib/python3.9/site-packages (from bleach>=2.1.0->readme-renderer>=35.0->twine->pyloco>=0.0.134->matplot) (0.5.1)
# Requirement already satisfied: mdurl~=0.1 in ./env/lib/python3.9/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich>=12.0.0->twine->pyloco>=0.0.134->matplot) (0.1.2)
# Requirement already satisfied: more-itertools in ./env/lib/python3.9/site-packages (from jaraco.classes->keyring>=15.1->twine->pyloco>=0.0.134->matplot) (9.1.0)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_excel('/Users/takshilrastogi/Desktop/flight-price-predictor/datasets/Data_Train.xlsx')
df
# Out:
#            Airline Date_of_Journey    Source Destination
# 0           IndiGo      24/03/2019  Banglore   New Delhi  \
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop  \
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2      DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3            CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4            BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# ...                      ...      ...           ...      ...         ...
# 10678              CCU → BLR    19:55         22:25   2h 30m    non-stop
# 10679              CCU → BLR    20:45         23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20         11:20       3h    non-stop
# 10681              BLR → DEL    11:30         14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55         19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 0             No info   3897
# 1             No info   7662
# 2             No info  13882
# 3             No info   6218
# 4             No info  13302
# ...               ...    ...
# 10678         No info   4107
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753
#
# [10683 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
df.isna().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Resolving journey month and date

# %%
df['Journey_day']= pd.to_datetime(df.Date_of_Journey, format='%d/%m/%Y').dt.day

# %%
df['Journey_month']=pd.to_datetime(df.Date_of_Journey, format='%d/%m/%Y').dt.month
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL  \
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897  \
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    Journey_day  Journey_month
# 0           24              3
# 1            1              5
# 2            9              6
# 3           12              5
# 4            1              3

# %%
df.drop(['Date_of_Journey'], axis=1, inplace=True)

# %% [markdown]
# ### Resolving time of departure

# %%
df['Dep_hour']=pd.to_datetime(df['Dep_Time']).dt.hour
df['Dep_min']=pd.to_datetime(df['Dep_Time']).dt.minute
df
# Out:
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1393185022.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Dep_hour']=pd.to_datetime(df['Dep_Time']).dt.hour
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1393185022.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Dep_min']=pd.to_datetime(df['Dep_Time']).dt.minute
#            Airline    Source Destination                  Route Dep_Time
# 0           IndiGo  Banglore   New Delhi              BLR → DEL    22:20  \
# 1        Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR    05:50
# 2      Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK    09:25
# 3           IndiGo   Kolkata    Banglore        CCU → NAG → BLR    18:05
# 4           IndiGo  Banglore   New Delhi        BLR → NAG → DEL    16:50
# ...            ...       ...         ...                    ...      ...
# 10678     Air Asia   Kolkata    Banglore              CCU → BLR    19:55
# 10679    Air India   Kolkata    Banglore              CCU → BLR    20:45
# 10680  Jet Airways  Banglore       Delhi              BLR → DEL    08:20
# 10681      Vistara  Banglore   New Delhi              BLR → DEL    11:30
# 10682    Air India     Delhi      Cochin  DEL → GOI → BOM → COK    10:55
#
#        Arrival_Time Duration Total_Stops Additional_Info  Price  Journey_day
# 0      01:10 22 Mar   2h 50m    non-stop         No info   3897           24  \
# 1             13:15   7h 25m     2 stops         No info   7662            1
# 2      04:25 10 Jun      19h     2 stops         No info  13882            9
# 3             23:30   5h 25m      1 stop         No info   6218           12
# 4             21:35   4h 45m      1 stop         No info  13302            1
# ...             ...      ...         ...             ...    ...          ...
# 10678         22:25   2h 30m    non-stop         No info   4107            9
# 10679         23:20   2h 35m    non-stop         No info   4145           27
# 10680         11:20       3h    non-stop         No info   7229           27
# 10681         14:10   2h 40m    non-stop         No info  12648            1
# 10682         19:15   8h 20m     2 stops         No info  11753            9
#
#        Journey_month  Dep_hour  Dep_min
# 0                  3        22       20
# 1                  5         5       50
# 2                  6         9       25
# 3                  5        18        5
# 4                  3        16       50
# ...              ...       ...      ...
# 10678              4        19       55
# 10679              4        20       45
# 10680              4         8       20
# 10681              3        11       30
# 10682              5        10       55
#
# [10682 rows x 14 columns]

# %%
df.drop(['Dep_Time'], axis=1, inplace=True)

# %%
df.head()
# Out:
#        Airline    Source Destination                  Route  Arrival_Time
# 0       IndiGo  Banglore   New Delhi              BLR → DEL  01:10 22 Mar  \
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR         13:15
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK  04:25 10 Jun
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR         23:30
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL         21:35
#
#   Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month
# 0   2h 50m    non-stop         No info   3897           24              3  \
# 1   7h 25m     2 stops         No info   7662            1              5
# 2      19h     2 stops         No info  13882            9              6
# 3   5h 25m      1 stop         No info   6218           12              5
# 4   4h 45m      1 stop         No info  13302            1              3
#
#    Dep_hour  Dep_min
# 0        22       20
# 1         5       50
# 2         9       25
# 3        18        5
# 4        16       50

# %% [markdown]
# ### Resolving time of arrival

# %%
df['Arrival_hour']=pd.to_datetime(df['Arrival_Time']).dt.hour
df['Arrival_min']=pd.to_datetime(df['Arrival_Time']).dt.minute
# Out:
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1428508412.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival_hour']=pd.to_datetime(df['Arrival_Time']).dt.hour
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1428508412.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['Arrival_min']=pd.to_datetime(df['Arrival_Time']).dt.minute

# %%
df.drop(['Arrival_Time'], axis=1, inplace=True)
df.head()
# Out:
#        Airline    Source Destination                  Route Duration
# 0       IndiGo  Banglore   New Delhi              BLR → DEL   2h 50m  \
# 1    Air India   Kolkata    Banglore  CCU → IXR → BBI → BLR   7h 25m
# 2  Jet Airways     Delhi      Cochin  DEL → LKO → BOM → COK      19h
# 3       IndiGo   Kolkata    Banglore        CCU → NAG → BLR   5h 25m
# 4       IndiGo  Banglore   New Delhi        BLR → NAG → DEL   4h 45m
#
#   Total_Stops Additional_Info  Price  Journey_day  Journey_month  Dep_hour
# 0    non-stop         No info   3897           24              3        22  \
# 1     2 stops         No info   7662            1              5         5
# 2     2 stops         No info  13882            9              6         9
# 3      1 stop         No info   6218           12              5        18
# 4      1 stop         No info  13302            1              3        16
#
#    Dep_min  Arrival_hour  Arrival_min
# 0       20             1           10
# 1       50            13           15
# 2       25             4           25
# 3        5            23           30
# 4       50            21           35

# %%
#converting duration time

duration=list(df['Duration'])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"
        else:
            duration[i] = "0h " + duration[i]

duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))

# %%
df['Duration_hours']=duration_hours
df['Duration_mins']=duration_mins
df = df.sort_values(by='Price', ascending=False)
df.head(50)
# Out:
#                     Airline    Source Destination                  Route
# 2924   Jet Airways Business  Banglore   New Delhi        BLR → BOM → DEL  \
# 5372   Jet Airways Business  Banglore   New Delhi        BLR → BOM → DEL
# 10364  Jet Airways Business  Banglore   New Delhi        BLR → MAA → DEL
# 1478            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 5439            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 2618            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 9715   Jet Airways Business     Delhi      Cochin  DEL → ATQ → BOM → COK
# 657    Jet Airways Business  Banglore   New Delhi        BLR → BOM → DEL
# 7351   Jet Airways Business     Delhi      Cochin  DEL → ATQ → BOM → COK
# 396       Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 2099            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 5719            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 2693            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 8598      Multiple carriers     Delhi      Cochin  DEL → IDR → BOM → COK
# 7617      Multiple carriers     Delhi      Cochin  DEL → IDR → BOM → COK
# 6991      Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 10052             Air India   Kolkata    Banglore              CCU → BLR
# 3700            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 5662            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 10439           Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 6576            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 5013            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 9019            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 1629              Air India  Banglore   New Delhi  BLR → BOM → NAG → DEL
# 7356      Multiple carriers     Delhi      Cochin        DEL → BOM → COK
# 5986              Air India     Delhi      Cochin        DEL → BOM → COK
# 3032            Jet Airways  Banglore   New Delhi        BLR → BDQ → DEL
# 6605            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 7724            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 9632            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 10189           Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 946             Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 1654            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 4829            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 8470            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 3111            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 123               Air India     Delhi      Cochin        DEL → BOM → COK
# 9193              Air India     Delhi      Cochin        DEL → BLR → COK
# 2108            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 628             Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 486             Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 8451            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 7713            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 826             Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 5710            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 8957            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 1246            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 959             Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 2495            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
# 7554            Jet Airways  Banglore   New Delhi        BLR → BOM → DEL
#
#       Duration Total_Stops Additional_Info  Price  Journey_day  Journey_month
# 2924    5h 40m      1 stop  Business class  79512            1              3  \
# 5372    6h 40m      1 stop  Business class  62427            1              3
# 10364   4h 40m      1 stop  Business class  57209            1              3
# 1478     6h 5m      1 stop         No info  54826           18              3
# 5439     6h 5m      1 stop         No info  54826            1              3
# 2618    6h 15m      1 stop         No info  54826           18              3
# 9715    8h 20m     2 stops         No info  52285            6              3
# 657         5h      1 stop         No info  52229            1              3
# 7351    8h 20m     2 stops         No info  46490            3              3
# 396     6h 25m      1 stop         No info  36983            1              3
# 2099     5h 5m      1 stop         No info  36235            1              3
# 5719    7h 15m      1 stop         No info  36235            1              3
# 2693     6h 5m      1 stop         No info  35185            1              3
# 8598   10h 30m     2 stops         No info  34608            9              3
# 7617   10h 30m     2 stops         No info  34503            3              3
# 6991   12h 40m      1 stop         No info  34273            9              5
# 10052   2h 35m    non-stop         No info  31945           24              3
# 3700   10h 40m      1 stop  1 Long layover  31825            1              3
# 5662   14h 50m      1 stop         No info  31825            1              3
# 10439  14h 20m      1 stop         No info  31825            1              3
# 6576   14h 50m      1 stop  1 Long layover  31825            1              3
# 5013   11h 35m      1 stop  1 Long layover  31825            1              3
# 9019   12h 35m      1 stop  1 Long layover  31825            1              3
# 1629   25h 45m     2 stops         No info  31783            1              3
# 7356       13h      1 stop         No info  29528            1              3
# 5986   27h 40m      1 stop         No info  28322            1              3
# 3032    6h 30m      1 stop  Business class  28097            1              3
# 6605   14h 20m      1 stop         No info  27992            1              3
# 7724   12h 25m      1 stop  1 Long layover  27992            1              3
# 9632   15h 35m      1 stop         No info  27992            1              3
# 10189  13h 20m      1 stop         No info  27992            1              3
# 946    13h 25m      1 stop         No info  27992            1              3
# 1654   12h 20m      1 stop         No info  27992            1              3
# 4829   14h 35m      1 stop         No info  27992            1              3
# 8470    6h 15m      1 stop         No info  27992            1              3
# 3111    9h 40m      1 stop  1 Long layover  27992            1              3
# 123    20h 15m      1 stop         No info  27430            1              3
# 9193   13h 15m      1 stop         No info  27282            3              3
# 2108    7h 40m      1 stop         No info  27210           15              3
# 628     6h 10m      1 stop         No info  27210           15              3
# 486     6h 20m      1 stop         No info  26890            1              3
# 8451    6h 15m      1 stop         No info  26890            1              3
# 7713   11h 25m      1 stop         No info  26890            1              3
# 826    10h 25m      1 stop         No info  26890            1              3
# 5710   15h 50m      1 stop         No info  26890            1              3
# 8957   20h 10m      1 stop  1 Long layover  26890            1              3
# 1246    7h 15m      1 stop         No info  26890            1              3
# 959     13h 5m      1 stop         No info  26890            1              3
# 2495   14h 45m      1 stop  1 Long layover  26890            1              3
# 7554   10h 40m      1 stop         No info  26890            1              3
#
#        Dep_hour  Dep_min  Arrival_hour  Arrival_min  Duration_hours
# 2924          5       45            11           25               5  \
# 5372          5       45            12           25               6
# 10364         9       45            14           25               4
# 1478         18       40             0           45               6
# 5439         16       55            23            0               6
# 2618         22       50             5            5               6
# 9715         20        5             4           25               8
# 657           5       45            10           45               5
# 7351         20        5             4           25               8
# 396          12       50            19           15               6
# 2099         14        5            19           10               5
# 5719         14        5            21           20               7
# 2693         18       40             0           45               6
# 8598         15        5             1           35              10
# 7617         15        5             1           35              10
# 6991         12       50             1           30              12
# 10052        20       45            23           20               2
# 3700         22       50             9           30              10
# 5662         20       35            11           25              14
# 10439        18       40             9            0              14
# 6576         18       40             9           30              14
# 5013         22       50            10           25              11
# 9019         22       50            11           25              12
# 1629          8       50            10           35              25
# 7356          0       20            13           20              13
# 5986          4        0             7           40              27
# 3032          5       50            12           20               6
# 6605          7        0            21           20              14
# 7724          8       55            21           20              12
# 9632          5       45            21           20              15
# 10189         7        0            20           20              13
# 946           5       45            19           10              13
# 1654          8        0            20           20              12
# 4829          5       45            20           20              14
# 8470         14        5            20           20               6
# 3111         11       40            21           20               9
# 123          23        0            19           15              20
# 9193          9       45            23            0              13
# 2108         21       25             5            5               7
# 628          22       55             5            5               6
# 486           8       55            15           15               6
# 8451         22       50             5            5               6
# 7713          7        0            18           25              11
# 826           5       45            16           10              10
# 5710          8       55             0           45              15
# 8957          8       55             5            5              20
# 1246          8       55            16           10               7
# 959          11       40             0           45              13
# 2495         16       55             7           40              14
# 7554         14        5             0           45              10
#
#        Duration_mins
# 2924              40
# 5372              40
# 10364             40
# 1478               5
# 5439               5
# 2618              15
# 9715              20
# 657                0
# 7351              20
# 396               25
# 2099               5
# 5719              15
# 2693               5
# 8598              30
# 7617              30
# 6991              40
# 10052             35
# 3700              40
# 5662              50
# 10439             20
# 6576              50
# 5013              35
# 9019              35
# 1629              45
# 7356               0
# 5986              40
# 3032              30
# 6605              20
# 7724              25
# 9632              35
# 10189             20
# 946               25
# 1654              20
# 4829              35
# 8470              15
# 3111              40
# 123               15
# 9193              15
# 2108              40
# 628               10
# 486               20
# 8451              15
# 7713              25
# 826               25
# 5710              50
# 8957              10
# 1246              15
# 959                5
# 2495              45
# 7554              40

# %%
df.drop(['Duration'], axis=1, inplace=True)


sns.catplot(y = "Price", x = "Airline", data = df.sort_values("Price", ascending = False), kind="boxen", height = 8, aspect = 3)
plt.show()

# %% [markdown]
# ### Handling categoriacal data

# %%
df['Airline'].value_counts()
# Out:
# Airline
# Jet Airways                          3849
# IndiGo                               2053
# Air India                            1751
# Multiple carriers                    1196
# SpiceJet                              818
# Vistara                               479
# Air Asia                              319
# GoAir                                 194
# Multiple carriers Premium economy      13
# Jet Airways Business                    6
# Vistara Premium economy                 3
# Trujet                                  1
# Name: count, dtype: int64

# %%
Airline=df[['Airline']]
Airline=pd.get_dummies(Airline,  drop_first=True)
Airline.head()
# Out:
#        Airline_Air India  Airline_GoAir  Airline_IndiGo  Airline_Jet Airways
# 2924               False          False           False                False  \
# 5372               False          False           False                False
# 10364              False          False           False                False
# 1478               False          False           False                 True
# 5439               False          False           False                 True
#
#        Airline_Jet Airways Business  Airline_Multiple carriers
# 2924                           True                      False  \
# 5372                           True                      False
# 10364                          True                      False
# 1478                          False                      False
# 5439                          False                      False
#
#        Airline_Multiple carriers Premium economy  Airline_SpiceJet
# 2924                                       False             False  \
# 5372                                       False             False
# 10364                                      False             False
# 1478                                       False             False
# 5439                                       False             False
#
#        Airline_Trujet  Airline_Vistara  Airline_Vistara Premium economy
# 2924            False            False                            False
# 5372            False            False                            False
# 10364           False            False                            False
# 1478            False            False                            False
# 5439            False            False                            False

# %%
df['Source'].value_counts()
# Out:
# Source
# Delhi       4536
# Kolkata     2871
# Banglore    2197
# Mumbai       697
# Chennai      381
# Name: count, dtype: int64

# %%
Source=df[['Source']]
Source=pd.get_dummies(Source, drop_first=True)
Source.head()
# Out:
#        Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 2924            False         False           False          False
# 5372            False         False           False          False
# 10364           False         False           False          False
# 1478            False         False           False          False
# 5439            False         False           False          False

# %%
df['Destination'].value_counts()
# Out:
# Destination
# Cochin       4536
# Banglore     2871
# Delhi        1265
# New Delhi     932
# Hyderabad     697
# Kolkata       381
# Name: count, dtype: int64

# %%
Destination=df[['Destination']]
Destination=pd.get_dummies(Destination, drop_first=True)
Destination.head()
# Out:
#        Destination_Cochin  Destination_Delhi  Destination_Hyderabad
# 2924                False              False                  False  \
# 5372                False              False                  False
# 10364               False              False                  False
# 1478                False              False                  False
# 5439                False              False                  False
#
#        Destination_Kolkata  Destination_New Delhi
# 2924                 False                   True
# 5372                 False                   True
# 10364                False                   True
# 1478                 False                   True
# 5439                 False                   True

# %%
df.drop(['Route', 'Additional_Info'], axis=1, inplace=True)

# %%
df['Total_Stops'].value_counts()
# Out:
# Total_Stops
# 1 stop      5625
# non-stop    3491
# 2 stops     1520
# 3 stops       45
# 4 stops        1
# Name: count, dtype: int64

# %%
df.replace({'non-stop':0, '1 stop':1, '2 stops':2, '3 stops':3, '4 stops':4}, inplace=True)

# %%
df.head()
# Out:
#                     Airline    Source Destination  Total_Stops  Price
# 2924   Jet Airways Business  Banglore   New Delhi            1  79512  \
# 5372   Jet Airways Business  Banglore   New Delhi            1  62427
# 10364  Jet Airways Business  Banglore   New Delhi            1  57209
# 1478            Jet Airways  Banglore   New Delhi            1  54826
# 5439            Jet Airways  Banglore   New Delhi            1  54826
#
#        Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour
# 2924             1              3         5       45            11  \
# 5372             1              3         5       45            12
# 10364            1              3         9       45            14
# 1478            18              3        18       40             0
# 5439             1              3        16       55            23
#
#        Arrival_min  Duration_hours  Duration_mins
# 2924            25               5             40
# 5372            25               6             40
# 10364           25               4             40
# 1478            45               6              5
# 5439             0               6              5

# %%
data_train=pd.concat([df, Airline, Source, Destination], axis=1)
data_train.head()
# Out:
#                     Airline    Source Destination  Total_Stops  Price
# 2924   Jet Airways Business  Banglore   New Delhi            1  79512  \
# 5372   Jet Airways Business  Banglore   New Delhi            1  62427
# 10364  Jet Airways Business  Banglore   New Delhi            1  57209
# 1478            Jet Airways  Banglore   New Delhi            1  54826
# 5439            Jet Airways  Banglore   New Delhi            1  54826
#
#        Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour
# 2924             1              3         5       45            11  \
# 5372             1              3         5       45            12
# 10364            1              3         9       45            14
# 1478            18              3        18       40             0
# 5439             1              3        16       55            23
#
#        Arrival_min  Duration_hours  Duration_mins  Airline_Air India
# 2924            25               5             40              False  \
# 5372            25               6             40              False
# 10364           25               4             40              False
# 1478            45               6              5              False
# 5439             0               6              5              False
#
#        Airline_GoAir  Airline_IndiGo  Airline_Jet Airways
# 2924           False           False                False  \
# 5372           False           False                False
# 10364          False           False                False
# 1478           False           False                 True
# 5439           False           False                 True
#
#        Airline_Jet Airways Business  Airline_Multiple carriers
# 2924                           True                      False  \
# 5372                           True                      False
# 10364                          True                      False
# 1478                          False                      False
# 5439                          False                      False
#
#        Airline_Multiple carriers Premium economy  Airline_SpiceJet
# 2924                                       False             False  \
# 5372                                       False             False
# 10364                                      False             False
# 1478                                       False             False
# 5439                                       False             False
#
#        Airline_Trujet  Airline_Vistara  Airline_Vistara Premium economy
# 2924            False            False                            False  \
# 5372            False            False                            False
# 10364           False            False                            False
# 1478            False            False                            False
# 5439            False            False                            False
#
#        Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 2924            False         False           False          False  \
# 5372            False         False           False          False
# 10364           False         False           False          False
# 1478            False         False           False          False
# 5439            False         False           False          False
#
#        Destination_Cochin  Destination_Delhi  Destination_Hyderabad
# 2924                False              False                  False  \
# 5372                False              False                  False
# 10364               False              False                  False
# 1478                False              False                  False
# 5439                False              False                  False
#
#        Destination_Kolkata  Destination_New Delhi
# 2924                 False                   True
# 5372                 False                   True
# 10364                False                   True
# 1478                 False                   True
# 5439                 False                   True

# %%
data_train.drop(['Airline', 'Source', 'Destination'], axis=1, inplace=True)

# %%
data_train.head()
# Out:
#        Total_Stops  Price  Journey_day  Journey_month  Dep_hour  Dep_min
# 2924             1  79512            1              3         5       45  \
# 5372             1  62427            1              3         5       45
# 10364            1  57209            1              3         9       45
# 1478             1  54826           18              3        18       40
# 5439             1  54826            1              3        16       55
#
#        Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# 2924             11           25               5             40  \
# 5372             12           25               6             40
# 10364            14           25               4             40
# 1478              0           45               6              5
# 5439             23            0               6              5
#
#        Airline_Air India  Airline_GoAir  Airline_IndiGo  Airline_Jet Airways
# 2924               False          False           False                False  \
# 5372               False          False           False                False
# 10364              False          False           False                False
# 1478               False          False           False                 True
# 5439               False          False           False                 True
#
#        Airline_Jet Airways Business  Airline_Multiple carriers
# 2924                           True                      False  \
# 5372                           True                      False
# 10364                          True                      False
# 1478                          False                      False
# 5439                          False                      False
#
#        Airline_Multiple carriers Premium economy  Airline_SpiceJet
# 2924                                       False             False  \
# 5372                                       False             False
# 10364                                      False             False
# 1478                                       False             False
# 5439                                       False             False
#
#        Airline_Trujet  Airline_Vistara  Airline_Vistara Premium economy
# 2924            False            False                            False  \
# 5372            False            False                            False
# 10364           False            False                            False
# 1478            False            False                            False
# 5439            False            False                            False
#
#        Source_Chennai  Source_Delhi  Source_Kolkata  Source_Mumbai
# 2924            False         False           False          False  \
# 5372            False         False           False          False
# 10364           False         False           False          False
# 1478            False         False           False          False
# 5439            False         False           False          False
#
#        Destination_Cochin  Destination_Delhi  Destination_Hyderabad
# 2924                False              False                  False  \
# 5372                False              False                  False
# 10364               False              False                  False
# 1478                False              False                  False
# 5439                False              False                  False
#
#        Destination_Kolkata  Destination_New Delhi
# 2924                 False                   True
# 5372                 False                   True
# 10364                False                   True
# 1478                 False                   True
# 5439                 False                   True

# %%
data_train.shape
# Out:
# (10682, 30)

# %% [markdown]
# ## Similar operations on testing dataset

# %%
test_data=pd.read_excel('/Users/takshilrastogi/Desktop/flight-price-predictor/datasets/Test_set.xlsx')
test_data.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK  \
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2671 entries, 0 to 2670
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          2671 non-null   object
#  1   Date_of_Journey  2671 non-null   object
#  2   Source           2671 non-null   object
#  3   Destination      2671 non-null   object
#  4   Route            2671 non-null   object
#  5   Dep_Time         2671 non-null   object
#  6   Arrival_Time     2671 non-null   object
#  7   Duration         2671 non-null   object
#  8   Total_Stops      2671 non-null   object
#  9   Additional_Info  2671 non-null   object
# dtypes: object(10)
# memory usage: 208.8+ KB

# %%
test_data.dropna(inplace=True)

# %%
test_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# dtype: int64

# %%
#Complete data preprocessing

# Date_of_Journey
test_data["Journey_day"] = pd.to_datetime(test_data.Date_of_Journey, format="%d/%m/%Y").dt.day
test_data["Journey_month"] = pd.to_datetime(test_data["Date_of_Journey"], format = "%d/%m/%Y").dt.month
test_data.drop(["Date_of_Journey"], axis = 1, inplace = True)

# Dep_Time
test_data["Dep_hour"] = pd.to_datetime(test_data["Dep_Time"]).dt.hour
test_data["Dep_min"] = pd.to_datetime(test_data["Dep_Time"]).dt.minute
test_data.drop(["Dep_Time"], axis = 1, inplace = True)

# Arrival_Time
test_data["Arrival_hour"] = pd.to_datetime(test_data.Arrival_Time).dt.hour
test_data["Arrival_min"] = pd.to_datetime(test_data.Arrival_Time).dt.minute
test_data.drop(["Arrival_Time"], axis = 1, inplace = True)

# Duration
duration = list(test_data["Duration"])

for i in range(len(duration)):
    if len(duration[i].split()) != 2:    # Check if duration contains only hour or mins
        if "h" in duration[i]:
            duration[i] = duration[i].strip() + " 0m"   # Adds 0 minute
        else:
            duration[i] = "0h " + duration[i]           # Adds 0 hour

duration_hours = []
duration_mins = []
for i in range(len(duration)):
    duration_hours.append(int(duration[i].split(sep = "h")[0]))    # Extract hours from duration
    duration_mins.append(int(duration[i].split(sep = "m")[0].split()[-1]))   # Extracts only minutes from duration

# Adding Duration column to test set
test_data["Duration_hours"] = duration_hours
test_data["Duration_mins"] = duration_mins
test_data.drop(["Duration"], axis = 1, inplace = True)
# Out:
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1801308414.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Dep_hour"] = pd.to_datetime(test_data["Dep_Time"]).dt.hour
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1801308414.py:10: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Dep_min"] = pd.to_datetime(test_data["Dep_Time"]).dt.minute
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1801308414.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Arrival_hour"] = pd.to_datetime(test_data.Arrival_Time).dt.hour
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/1801308414.py:15: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_data["Arrival_min"] = pd.to_datetime(test_data.Arrival_Time).dt.minute

# %%
test_data.head()
# Out:
#              Airline    Source Destination            Route Total_Stops
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop  \
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR      1 stop
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK      1 stop
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      1 stop
# 4           Air Asia  Banglore       Delhi        BLR → DEL    non-stop
#
#                Additional_Info  Journey_day  Journey_month  Dep_hour  Dep_min
# 0                      No info            6              6        17       30  \
# 1                      No info           12              5         6       20
# 2  In-flight meal not included           21              5        19       15
# 3                      No info           21              5         8        0
# 4                      No info           24              6        23       55
#
#    Arrival_hour  Arrival_min  Duration_hours  Duration_mins
# 0             4           25              10             55
# 1            10           20               4              0
# 2            19            0              23             45
# 3            21            0              13              0
# 4             2           45               2             50

# %% [markdown]
# ### Handling categorical data

# %%
Airline = pd.get_dummies(test_data["Airline"], drop_first= True)
Source = pd.get_dummies(test_data["Source"], drop_first= True)
Destination = pd.get_dummies(test_data["Destination"], drop_first = True)

# %%
test_data.drop(["Route", "Additional_Info"], axis = 1, inplace = True)
test_data.replace({"non-stop": 0, "1 stop": 1, "2 stops": 2, "3 stops": 3, "4 stops": 4}, inplace = True)
data_test = pd.concat([test_data, Airline, Source, Destination], axis = 1)
data_test.drop(["Airline", "Source", "Destination"], axis = 1, inplace = True)

# %%
data_test.head()
# Out:
#    Total_Stops  Journey_day  Journey_month  Dep_hour  Dep_min  Arrival_hour
# 0            1            6              6        17       30             4  \
# 1            1           12              5         6       20            10
# 2            1           21              5        19       15            19
# 3            1           21              5         8        0            21
# 4            0           24              6        23       55             2
#
#    Arrival_min  Duration_hours  Duration_mins  Air India  GoAir  IndiGo
# 0           25              10             55      False  False   False  \
# 1           20               4              0      False  False    True
# 2            0              23             45      False  False   False
# 3            0              13              0      False  False   False
# 4           45               2             50      False  False   False
#
#    Jet Airways  Jet Airways Business  Multiple carriers
# 0         True                 False              False  \
# 1        False                 False              False
# 2         True                 False              False
# 3        False                 False               True
# 4        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Vistara
# 0                              False     False    False  \
# 1                              False     False    False
# 2                              False     False    False
# 3                              False     False    False
# 4                              False     False    False
#
#    Vistara Premium economy  Chennai  Delhi  Kolkata  Mumbai  Cochin  Delhi
# 0                    False    False   True    False   False    True  False  \
# 1                    False    False  False     True   False   False  False
# 2                    False    False   True    False   False    True  False
# 3                    False    False   True    False   False    True  False
# 4                    False    False  False    False   False   False   True
#
#    Hyderabad  Kolkata  New Delhi
# 0      False    False      False
# 1      False    False      False
# 2      False    False      False
# 3      False    False      False
# 4      False    False      False

# %% [markdown]
# ## Feature selection

# %%
x=data_train.loc[:, ['Total_Stops', 'Journey_day', 'Journey_month', 'Dep_hour',
       'Dep_min', 'Arrival_hour', 'Arrival_min', 'Duration_hours',
       'Duration_mins', 'Airline_Air India', 'Airline_GoAir', 'Airline_IndiGo',
       'Airline_Jet Airways', 'Airline_Jet Airways Business',
       'Airline_Multiple carriers',
       'Airline_Multiple carriers Premium economy', 'Airline_SpiceJet',
       'Airline_Trujet', 'Airline_Vistara', 'Airline_Vistara Premium economy',
       'Source_Chennai', 'Source_Delhi', 'Source_Kolkata', 'Source_Mumbai',
       'Destination_Cochin', 'Destination_Delhi', 'Destination_Hyderabad',
       'Destination_Kolkata', 'Destination_New Delhi']]
x.head()
print(x.shape);
# Out:
# (10682, 29)

# %%
y=data_train.iloc[:, 1]
y.head()
# Out:
# 2924     79512
# 5372     62427
# 10364    57209
# 1478     54826
# 5439     54826
# Name: Price, dtype: int64

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
#using various regression algorithms to predict
#multiple linear regression
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train, y_train)
y_pred = regressor.predict(x_test)
regressor.score(x_train, y_train)
# Out:
# 0.6268768970262155

# %%
regressor.score(x_train, y_train)
# Out:
# 0.6268768970262155

# %%
#decision tree regression
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(x_train, y_train)
y_pred=regressor.predict(x_test)
regressor.score(x_train, y_train)
# Out:
# 0.9716838744779073

# %%
regressor.score(x_test, y_test)
# Out:
# 0.7056749071803031

# %%
#using random forest regression
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=100, random_state=0)
regressor.fit(x_train, y_train)
y_pred=regressor.predict(x_test)
regressor.score(x_train, y_train)
# Out:
# 0.95534884215206

# %%
regressor.score(x_test, y_test)
# Out:
# 0.7989569101304114

# %% [markdown]
# ### We are getting the highest accuracy for random forest for testing dataset.

# %%
sns.distplot(y_test-y_pred)
plt.show()
# Out:
# /var/folders/n9/5dh9tpc57dddst3b6cdmr7xm0000gn/T/ipykernel_11252/3453123835.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_test-y_pred)

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.7989569101304114

# %% [markdown]
# ## Saving the model to use it again

# %%
import pickle

# %%
file = open('flight_model.pkl', 'wb')

# %%
pickle.dump(regressor, file)

# %%
model=open('flight_model.pkl', 'rb')
flight_price=pickle.load(model)
